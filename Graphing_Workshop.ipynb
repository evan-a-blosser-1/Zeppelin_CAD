# %%
import numpy as np
import matplotlib.pyplot as plt 
import sympy as sp

# %%
def B_spline():
    # Length envelope
    L = 10 
    ######
    p1x = 0
    p1y = 0
    p1z = 0
    p2x = L*(1/3)
    p2y = 0
    p2z = 5
    p3x = L*(2/3)
    p3y = 0
    p3z = 5
    p4x = L
    p4y = 0
    p4z = 0
    #########
    p_i = np.array([[p1x,p1y,p1z],[p2x,p2y,p2z],[p3x,p3y,p3z],[p4x,p4y,p4z]])
    ##############
    u = sp.symbols('u')
    U = np.array([[u**3, u**2, u, 1]])
    M = np.array([[-9/2 ,27/2, -27/2, 9/2],[9, -45/2, 18, -9/2],[-11/2, 9, -9/2, 1], [1, 0 ,0 ,0 ]])
    # print(M)
    P = U*M*p_i
    ######
    u_val = np.linspace(0, L, 100)
    ###### 
    
    return

# %%
# Length envelope
L = 10 
######
p1x = 0
p1y = 0
p1z = 0
p2x = L*(1/3)
p2y = 0
p2z = 5
p3x = L*(2/3)
p3y = 0
p3z = 5
p4x = L
p4y = 0
p4z = 0
#########
p_i = np.array([[p1x,p1y,p1z],[p2x,p2y,p2z],[p3x,p3y,p3z],[p4x,p4y,p4z]])
##############
u = sp.symbols('u')
U = np.array([[u**3, u**2, u, 1]])
M = np.array([[-9/2 ,27/2, -27/2, 9/2],[9, -45/2, 18, -9/2],[-11/2, 9, -9/2, 1], [1, 0 ,0 ,0 ]])
print(M)
print(U)
print(p_i)
# Curve Eq. 
P = U@M@p_i
print(P)
######
u = np.linspace(0, L, 100)
###### 

print(P)
# Out:
# [[ -4.5  13.5 -13.5   4.5]
#  [  9.  -22.5  18.   -4.5]
#  [ -5.5   9.   -4.5   1. ]
#  [  1.    0.    0.    0. ]]
# [[u**3 u**2 u 1]]
# [[ 0.          0.          0.        ]
#  [ 3.33333333  0.          5.        ]
#  [ 6.66666667  0.          5.        ]
#  [10.          0.          0.        ]]
# [[7.105427357601e-15*u**3 - 1.4210854715202e-14*u**2 + 10.0*u 0
#   -22.5*u**2 + 22.5*u]]
# [[7.105427357601e-15*u**3 - 1.4210854715202e-14*u**2 + 10.0*u 0
#   -22.5*u**2 + 22.5*u]]
